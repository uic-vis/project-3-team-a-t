# %%
import pandas as pd

df = pd.read_csv("COVID-19_Cases__Tests__and_Deaths_by_ZIP_Code.csv")
df
# Out:
#      ZIP Code  Week Number  Week Start    Week End  Cases - Weekly  \
# 0       60602            1  01/02/2022  01/08/2022              45
# 1       60612            1  01/02/2022  01/08/2022             604
# 2       60613            1  01/02/2022  01/08/2022             767
# 3       60614            1  01/02/2022  01/08/2022             927
# 4       60615            1  01/02/2022  01/08/2022             588
# ...       ...          ...         ...         ...             ...
# 2755    60618           46  11/13/2022  11/19/2022              82
# 2756    60654           46  11/13/2022  11/19/2022              14
# 2757    60660           46  11/13/2022  11/19/2022              56
# 2758    60634           46  11/13/2022  11/19/2022              92
# 2759  Unknown           46  11/13/2022  11/19/2022              18
#
#       Cases - Cumulative  Case Rate - Weekly  Case Rate - Cumulative  \
# 0                    290                3617                 23311.9
# ...

# %%
df = df.dropna()
df
# Out:
#      ZIP Code  Week Number  Week Start    Week End  Cases - Weekly  \
# 0       60602            1  01/02/2022  01/08/2022              45
# 1       60612            1  01/02/2022  01/08/2022             604
# 2       60613            1  01/02/2022  01/08/2022             767
# 3       60614            1  01/02/2022  01/08/2022             927
# 4       60615            1  01/02/2022  01/08/2022             588
# ...       ...          ...         ...         ...             ...
# 2754    60613           46  11/13/2022  11/19/2022              36
# 2755    60618           46  11/13/2022  11/19/2022              82
# 2756    60654           46  11/13/2022  11/19/2022              14
# 2757    60660           46  11/13/2022  11/19/2022              56
# 2758    60634           46  11/13/2022  11/19/2022              92
#
#       Cases - Cumulative  Case Rate - Weekly  Case Rate - Cumulative  \
# 0                    290                3617                 23311.9
# ...

# %%
df = df[(df['Week Start'] > "10/01/2022") & (df['Week Start'] < "10/09/2022")]
df
# Out:
#      ZIP Code  Week Number  Week Start    Week End  Cases - Weekly  \
# 2340    60612           40  10/02/2022  10/08/2022              28
# 2341    60615           40  10/02/2022  10/08/2022              53
# 2342    60617           40  10/02/2022  10/08/2022              66
# 2343    60603           40  10/02/2022  10/08/2022               1
# 2344    60618           40  10/02/2022  10/08/2022              87
# 2345    60619           40  10/02/2022  10/08/2022              61
# 2346    60620           40  10/02/2022  10/08/2022              55
# 2347    60622           40  10/02/2022  10/08/2022              32
# 2348    60604           40  10/02/2022  10/08/2022               0
# 2349    60623           40  10/02/2022  10/08/2022              87
# 2350    60625           40  10/02/2022  10/08/2022              64
# 2351    60606           40  10/02/2022  10/08/2022              10
# 2352    60626           40  10/02/2022  10/08/2022              62
# ...

# %%
df.to_csv("zipData.csv")
#print(type(df["ZIP Code Location"][0]))
